# %%
import pandas as pd

# %%
df=pd.read_csv("../data/marketing_campaign_data .csv")

# %%
df.shape
# Out:
# (56000, 28)

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Response               0
# Complain               0
# Country                0
# dtype: int64

# %%
df.dtypes
# Out:
# ID                       int64
# Year_Birth               int64
# Education               object
# Marital_Status          object
# Income                 float64
# Kidhome                  int64
# Teenhome                 int64
# Dt_Customer             object
# Recency                  int64
# MntWines                 int64
# MntFruits                int64
# MntMeatProducts          int64
# MntFishProducts          int64
# MntSweetProducts         int64
# MntGoldProds             int64
# NumDealsPurchases        int64
# NumWebPurchases          int64
# NumCatalogPurchases      int64
# NumStorePurchases        int64
# NumWebVisitsMonth        int64
# AcceptedCmp3             int64
# AcceptedCmp4             int64
# AcceptedCmp5             int64
# AcceptedCmp1             int64
# AcceptedCmp2             int64
# Response                 int64
# Complain                 int64
# Country                 object
# dtype: object

# %%
numerical_cols = df.select_dtypes(
    include=["int64", "float64"]
).columns

print(numerical_cols)
# Out:
# Index(['ID', 'Year_Birth', 'Income', 'Kidhome', 'Teenhome', 'Recency',
#        'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
#        'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases',
#        'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
#        'NumWebVisitsMonth', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5',
#        'AcceptedCmp1', 'AcceptedCmp2', 'Response', 'Complain'],
#       dtype='object')

# %% [markdown]
# Numerical columns:

# %%
num_cols = df.select_dtypes(
    include=["int64", "float64"]
).columns

print(num_cols)
# Out:
# Index(['ID', 'Year_Birth', 'Income', 'Kidhome', 'Teenhome', 'Recency',
#        'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
#        'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases',
#        'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
#        'NumWebVisitsMonth', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5',
#        'AcceptedCmp1', 'AcceptedCmp2', 'Response', 'Complain'],
#       dtype='object')

# %% [markdown]
# Categorical columns:

# %%
cat_cols = df.select_dtypes(
    include=["object"]
).columns

print(cat_cols)
# Out:
# Index(['Education', 'Marital_Status', 'Dt_Customer', 'Country'], dtype='object')

# %%
df.isnull().sum()[
    df.isnull().sum() > 0
]
# Out:
# Series([], dtype: int64)

# %%
df["Income"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#fix data Types
df["Dt_Customer"]=pd.to_datetime(
    df["Dt_Customer"]
)

# %%
df.info
# Out:
# <bound method DataFrame.info of              ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0        342199        1985  Graduation       Together  59011.7        1
# 1       8075450        1975      Master         Single   1730.0        1
# 2      13664263        1978  Graduation        Married  98584.6        0
# 3      16164787        1976  Graduation        Married  74031.5        1
# 4      15815139        1981  Graduation       Divorced  52784.2        1
# ...         ...         ...         ...            ...      ...      ...
# 55995   2485439        1985  Graduation        Married  32533.4        0
# 55996   9202496        1992       Basic         Single  70496.3        0
# 55997  14677746        1950  Graduation       Together  21072.0        1
# 55998   3843719        1976  Graduation       Together  64218.1        0
# 55999   3195751        1984  Graduation        Married  89322.8        0
#
#        Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 0             0  2012-11-17        3         0  ...                  3
# 1             1  2013-04-10       96         0  ...                  2
# 2             0  2014-01-11       99       920  ...                  6
# 3             0  2014-06-18       47       265  ...                 11
# 4             1  2014-05-20        0        30  ...                  3
# ...         ...         ...      ...       ...  ...                ...
# 55995         0  2013-04-05       99         8  ...                  6
# 55996         1  2013-01-31        9       835  ...                  8
# 55997         0  2013-06-25       24         0  ...                  0
# 55998         0  2014-05-12       81         8  ...                  1
# 55999         1  2013-09-04       93       113  ...                  1
#
#        NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# 0                      4             0             0             0
# 1                      3             0             0             0
# 2                      3             0             0             0
# 3                      4             0             0             0
# 4                      6             0             0             0
# ...                  ...           ...           ...           ...
# 55995                  8             0             0             0
# 55996                  4             0             0             0
# 55997                  3             0             0             0
# 55998                  8             0             0             0
# 55999                  4             0             0             0
#
#        AcceptedCmp1  AcceptedCmp2  Response  Complain       Country
# 0                 0             0         0         0         Spain
# 1                 0             0         0         0         Spain
# 2                 0             0         0         0     Australia
# 3                 0             0         0         0         Spain
# 4                 0             0         0         0        Canada
# ...             ...           ...       ...       ...           ...
# 55995             0             0         0         0     Australia
# 55996             0             0         0         0       Germany
# 55997             0             0         1         0  Saudi Arabia
# 55998             0             0         0         0  Saudi Arabia
# 55999             0             0         0         0  Saudi Arabia
#
# [56000 rows x 28 columns]>

# %%
df.describe()
# Out:
#                  ID    Year_Birth         Income       Kidhome      Teenhome  \
# count  5.600000e+04  56000.000000   56000.000000  56000.000000  56000.000000
# mean   8.389352e+06   1971.666696   57252.189521      0.539911      0.362143
# min    3.600000e+01   1936.000000    1730.000000      0.000000      0.000000
# 25%    4.187372e+06   1963.000000   28252.025000      0.000000      0.000000
# 50%    8.383784e+06   1973.000000   58838.550000      1.000000      0.000000
# 75%    1.258576e+07   1981.000000   86930.650000      1.000000      1.000000
# max    1.677716e+07   1996.000000  258027.500000      2.000000      2.000000
# std    4.844638e+06     12.211066   34307.247999      0.521349      0.510567
#
#                          Dt_Customer       Recency      MntWines  \
# count                          56000  56000.000000  56000.000000
# mean   2013-08-15 07:30:18.514285568     63.221107    246.981482
# min              2012-07-30 00:00:00      0.000000      0.000000
# 25%              2013-01-24 00:00:00     35.000000      0.000000
# 50%              2013-08-19 00:00:00     71.000000     64.000000
# 75%              2014-03-10 00:00:00     93.000000    353.000000
# max              2014-06-29 00:00:00     99.000000   1493.000000
# std                              NaN     31.157066    358.569481
#
#           MntFruits  MntMeatProducts  ...  NumCatalogPurchases  \
# count  56000.000000     56000.000000  ...         56000.000000
# mean      16.152661       268.294018  ...             2.110750
# min        0.000000         0.000000  ...             0.000000
# 25%        0.000000        42.000000  ...             0.000000
# 50%        0.000000       107.000000  ...             1.000000
# 75%       15.000000       363.000000  ...             3.000000
# max      199.000000      1341.000000  ...            14.000000
# std       33.931463       342.165712  ...             2.357824
#
#        NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  \
# count       56000.000000       56000.000000  56000.000000  56000.000000
# mean            4.706411           5.170107      0.062393      0.056821
# min             0.000000           0.000000      0.000000      0.000000
# 25%             3.000000           3.000000      0.000000      0.000000
# 50%             4.000000           6.000000      0.000000      0.000000
# 75%             6.000000           7.000000      0.000000      0.000000
# max            13.000000          10.000000      1.000000      1.000000
# std             2.896366           2.555911      0.241870      0.231503
#
#        AcceptedCmp5  AcceptedCmp1  AcceptedCmp2      Response      Complain
# count  56000.000000  56000.000000  56000.000000  56000.000000  56000.000000
# mean       0.045661      0.134446      0.014411      0.147589      0.007625
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
# std        0.208750      0.341134      0.119178      0.354696      0.086988
#
# [8 rows x 25 columns]

# %%
df.shape
# Out:
# (56000, 28)

# %%
df.isnull().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Response               0
# Complain               0
# Country                0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 55995    False
# 55996    False
# 55997    False
# 55998    False
# 55999    False
# Length: 56000, dtype: bool

# %%
df.dtypes
# Out:
# ID                              int64
# Year_Birth                      int64
# Education                      object
# Marital_Status                 object
# Income                        float64
# Kidhome                         int64
# Teenhome                        int64
# Dt_Customer            datetime64[ns]
# Recency                         int64
# MntWines                        int64
# MntFruits                       int64
# MntMeatProducts                 int64
# MntFishProducts                 int64
# MntSweetProducts                int64
# MntGoldProds                    int64
# NumDealsPurchases               int64
# NumWebPurchases                 int64
# NumCatalogPurchases             int64
# NumStorePurchases               int64
# NumWebVisitsMonth               int64
# AcceptedCmp3                    int64
# AcceptedCmp4                    int64
# AcceptedCmp5                    int64
# AcceptedCmp1                    int64
# AcceptedCmp2                    int64
# Response                        int64
# Complain                        int64
# Country                        object
# dtype: object

# %%
# DataFrame ko CSV me save karna
df.to_csv("../data/Clean_marketing_campaign_data.csv", index=False)
